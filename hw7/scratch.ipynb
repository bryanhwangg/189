# %%
from im2spain.im2spain_starter import *
import numpy as np

# %%
data = np.load("im2spain/im2spain_data.npz")
data.files
# Out:
# ['train_features',
#  'test_features',
#  'train_labels',
#  'test_labels',
#  'train_files',
#  'test_files']

# %%
train_X = data["train_features"]
train_y = data["train_labels"]

# %%
plot_data(train_X, train_y)
